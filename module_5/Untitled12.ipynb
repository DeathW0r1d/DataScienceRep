# %%
import pandas as pd

# %%
df = pd.read_csv('autoru_parse_Moscow2.csv',sep='\t', encoding='utf-8')
#df_2 = pd.read_csv('autoru_61k.csv')

# %%
df.drop(['Unnamed: 0'],axis = 1, inplace=True)

# %%
df.code.value_counts()
# Out:
# VOLKSWAGEN    1602
# TOYOTA        1543
# AUDI          1492
# BMW           1397
# NISSAN        1372
# SKODA         1303
# MITSUBISHI    1243
# MERCEDES      1019
# VOLVO          810
# HONDA          707
# LEXUS          662
# INFINITI       531
# Name: code, dtype: int64

# %%
df
# Out:
#       color_hex section      price  mileage  state_not_beaten  owners_number  \
# 0        FAFBFB    used  1276000.0   174000              True              1
# 1        EE1D19    used   502280.0   290000              True              3
# 2        FAFBFB    used  1933800.0    75500              True              2
# 3        FAFBFB    used  1496930.0   107983              True              2
# 4        007F00    used  2100000.0    52387              True              1
# ...         ...     ...        ...      ...               ...            ...
# 13676    CACECB    used   351000.0   351000              True              2
# 13677    040001    used   477000.0   286200              True              4
# 13678    CACECB    used   295800.0   301600              True              4
# 13679    0000CC    used   234000.0   526500              True              4
# 13680    CACECB    used   313501.5   288771              True              4
#
# ...

# %%
df= df.drop_duplicates(ignore_index=True)

# %%
df
# Out:
#       color_hex section      price  mileage  state_not_beaten  owners_number  \
# 0        FAFBFB    used  1276000.0   174000              True              1
# 1        EE1D19    used   502280.0   290000              True              3
# 2        FAFBFB    used  1933800.0    75500              True              2
# 3        FAFBFB    used  1496930.0   107983              True              2
# 4        007F00    used  2100000.0    52387              True              1
# ...         ...     ...        ...      ...               ...            ...
# 13676    CACECB    used   351000.0   351000              True              2
# 13677    040001    used   477000.0   286200              True              4
# 13678    CACECB    used   295800.0   301600              True              4
# 13679    0000CC    used   234000.0   526500              True              4
# 13680    CACECB    used   313501.5   288771              True              4
#
# ...

# %%
df.code.value_counts()
# Out:
# VOLKSWAGEN    1602
# TOYOTA        1543
# AUDI          1492
# BMW           1397
# NISSAN        1372
# SKODA         1303
# MITSUBISHI    1243
# MERCEDES      1019
# VOLVO          810
# HONDA          707
# LEXUS          662
# INFINITI       531
# Name: code, dtype: int64

# %%
df.to_csv('autoru_parse_Moscow2.csv', sep='\t', encoding='utf-8')
